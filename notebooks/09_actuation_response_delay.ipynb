# %%
import copy
from IPython.display import display, Image
import logging
import numpy
import os
import pandas
import pdb
import plotly
import pprint
import pyarrow
import pyarrow.parquet as pq
import six
import sys
import tensorflow as tf
import time

import CS230

plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
file_paths = CS230.data.get_all_file_paths()

# %%
file_path = file_paths[0]

df = CS230.data.load(file_path)
df = CS230.data.stride_rows(df, stride=100)
df = CS230.data.add_derivatives(df, stride=1)
df = CS230.data.clean_discontinuities(df, stride=1)

# %%
df.head()
# Out:
#    time  handwheelAngle  throttle  brake  clutch  engineSpeed  PPS   gpsTime  \
# 0   0.0            29.3       0.7    2.3    13.2          204  5.0  61377.09
# 1   0.1            29.4       0.7    0.0    13.2          204  5.0  61377.19
# 2   0.2            29.4       0.7    0.0    18.6          204  5.0  61377.29
# 3   0.3            29.4       0.7    0.0    24.5          204  5.0  61377.39
# 4   0.4            29.3       0.7    0.0    22.5          204  5.0  61377.49
#
#    latitude  longitude  ...  deriv_rollAngle  deriv_rollRate  deriv_vxCG  \
# 0       NaN        NaN  ...              0.0            0.00         0.0
# 1       NaN        NaN  ...              0.0            0.78         0.0
# 2       NaN        NaN  ...              0.0           -0.16         0.0
# 3       NaN        NaN  ...              0.0           -0.22         0.0
# 4       NaN        NaN  ...              0.0            0.42        -0.0
#
# ...

# %%
fig, image_path = CS230.data.plot(df, file_path, columns=['throttle'], plot=True, write=False)
# Out:
# <div>
#
#
#             <div id="5683272f-5c7c-4ab6-8f0d-6ecbf28f4b16" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5683272f-5c7c-4ab6-8f0d-6ecbf28f4b16")) {
#                     Plotly.newPlot(
#                         '5683272f-5c7c-4ab6-8f0d-6ecbf28f4b16',
# ...

# %%
fig, image_path = CS230.data.plot(df, file_path, columns=['throttle', 'vxCG', 'deriv_vxCG'], plot=True, write=False,
                                 start=12500, stop=13500, step=1)
# Out:
# <div>
#
#
#             <div id="785fedf3-b7cd-44ce-8e4a-e0af42efce88" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("785fedf3-b7cd-44ce-8e4a-e0af42efce88")) {
#                     Plotly.newPlot(
#                         '785fedf3-b7cd-44ce-8e4a-e0af42efce88',
# ...

# %%
fig, image_path = CS230.data.plot(df, file_path, columns=['brake', 'vxCG', 'deriv_vxCG'], plot=True, write=False,
                                 start=12500, stop=13500, step=1)
# Out:
# <div>
#
#
#             <div id="6b300dfb-64e9-4729-a39c-decb423371c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6b300dfb-64e9-4729-a39c-decb423371c7")) {
#                     Plotly.newPlot(
#                         '6b300dfb-64e9-4729-a39c-decb423371c7',
# ...
